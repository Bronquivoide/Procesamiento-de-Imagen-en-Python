# %% [markdown]
# # Componentes rojo, verde y azul de una imagen RGB:
#
# <span style="font-family: 'Verdana'; color: red;"> *Bronquivoide* </span>
#
# ### Este notebook pretende ser una extensión del notebook sobre fundamentos de imágenes RGB, pues el objetivo es explorar las componentes asociadas a una imagen en el espacio RGB.
#
# # Ejercicio 1:
#
# ### Explorar las componentes rojo, verde y azul de la famosa imagen usada en otros notebooks, *Verduras.jpg*.
#
# ### Primeramente vamos a hacer un pequeño análisis de la imagen:

# %%
import numpy as np
import matplotlib.pyplot as plt

im=plt.imread('Verduras.jpg')
plt.imshow(im)     
plt.title('Verduras')
plt.show()

# %%
print(f"El arreglo asociado a la imagen es:\n {im}")
print("")

print(f"El orden del arreglo es:\n {im.shape}")
print("")

print(f"El tipo de arreglo es:\n {type(im)}")
print("")

print(f"La dimensión del arreglo NumPy es:\n {im.ndim}")
print(" ")
# Out:
# El arreglo asociado a la imagen es:
#  [[[139  29  76]
#   [164  57 101]
#   [162  55  99]
#   ...
#   [174 135 138]
#   [172 133 136]
#   [150 130 139]]
#
#  [[162  68  14]
#   [188  95  38]
#   [183  90  31]
#   ...
#   [155 204  78]
#   [153 202  76]
#   [132 200  77]]
#
#  [[167  69  34]
#   [193  93  57]
#   [188  89  50]
#   ...
#   [153 203  88]
#   [151 201  86]
#   [129 199  87]]
#
#  ...
#
#  [[117  93  23]
#   [117 124  44]
#   [104 118  33]
#   ...
#   [209 201 178]
#   [163 220 179]
#   [182 209 168]]
#
#  [[ 99  85  12]
#   [133 144  65]
#   [110 115  35]
#   ...
#   [223 207 192]
#   [162 205 177]
#   [181 211 161]]
#
#  [[114  71  29]
#   [137 138  58]
#   [118 108  55]
#   ...
#   [178 218 165]
#   [177 204 171]
#   [185 195 160]]]
#
# El orden del arreglo es:
#  (225, 225, 3)
#
# El tipo de arreglo es:
#  <class 'numpy.ndarray'>
#
# La dimensión del arreglo NumPy es:
#  3

# %% [markdown]
# ### Del comando anterior vemos que la función *plt.imshow()* recibe tres matrices (una por componente) representadas en un arreglo tridimensional NumPy asociado a las componentes de color de la imagen para mostrarla.
#
# ### Podemos observar la imagen separándola por componentes. Vamos a extraer cada una de las componentes rojo, verde y azul de la imagen, y a mostrarlas individualmente. Para esto vamos a usar la función *plt.imshow()* aplicada sobre cada componente extraída.
#
# ### Para extraer cada componente usamos la función *imagen[ largo , ancho , componente (o canal) ]*. Como queremos únicamente mostrar cada componente a través de todo el largo y el ancho, vamos a establecer la función como *imagen[ : , : , $i$ ]*, en donde $i=0,1,2$ (rojo, verde, azul).

# %%
#R
plt.imshow(im[:,:,0])    
plt.title('Componente roja de Verduras.jpg',fontsize=20,color="r")
plt.show()

#G
plt.imshow(im[:,:,1])    
plt.title('Componente verde de Verduras.jpg',fontsize=20,color="g")
plt.show()

#B
plt.imshow(im[:,:,2])    
plt.title('Componente azul de Verduras.jpg',fontsize=20,color="b")
plt.show()

# %% [markdown]
# ### O bien, podemos visualizar las componentes en escala de grises, donde los valores de intensidad asociado a los pixeles de los canales RGB se interpretan como niveles de gris. Es decir,  los valores numéricos de la intensidad en RGB se interpretan en el rango de niveles de gris.

# %%
#R
plt.imshow(im[:,:,0],cmap='gray')    
plt.title('Componente roja de Verduras.jpg en escala de grises',fontsize=15,color="r")
plt.show()

#G
plt.imshow(im[:,:,1],cmap='gray')    
plt.title('Componente verde de Verduras.jpg en escala de grises',fontsize=15,color="g")
plt.show()

#B
plt.imshow(im[:,:,2],cmap='gray')    
plt.title('Componente azul de Verduras.jpg en escala de grises',fontsize=15,color="b")
plt.show()

# %% [markdown]
# # Ejercicio 2:
#
# ### Extraer cada una de las componentes RGB asociadas a una coordenada $(x_0,y_0)$
#
# ###  Recordemos que una imagen puede describirse mediante una función actuando sobre un conjunto de pares de coordenadas espaciales $\{(x,y)\}$. Por lo que vamos a extraer, por ejemplo, la intensidad de cada componente asociada al pixel $(100,100)$.
#
# ### Esto es, anteriormente extrajimos una componente particular a lo largo de todas las coordenadas $(M_i,N_i)$, con $i=0,1,...,225$, ahora queremos extraer todas las componentes en la coordenada $(100,100)$.

# %%
print(im[100, 100, :])
print("")

print(f"La intensidad de la componente roja en (100,100) es:\n {im[100, 100, 0]}")
print("")

print(f"La intensidad de la componente verde en (100,100) es:\n {im[100, 100, 1]}")
print("")

print(f"La intensidad de la componente azul en (100,100) es:\n {im[100, 100, 2]}")
print("")
# Out:
# [160  36  36]
#
# La intensidad de la componente roja en (100,100) es:
#  160
#
# La intensidad de la componente verde en (100,100) es:
#  36
#
# La intensidad de la componente azul en (100,100) es:
#  36

# %% [markdown]
# # Fin del ejercicio.
